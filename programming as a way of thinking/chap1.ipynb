# %% [markdown]
# # Arithmitic operators

# %% [markdown]
# these are symbols that represent an arithmitic computation. For example, the + sign preforms addition

# %%
55 + 12
# Out:
# 67

# %%
# The - sign is for subtraction
79 - 12
# Out:
# 67

# %%
# The * is for multiplication
6 * 7
# Out:
# 42

# %%
# The / symbol used for divison 
134 / 2
# Out:
# 67.0

# %% [markdown]
# ### When you divide in python, the answer will always be a datatype called a float.

# %% [markdown]
# #### initger represents a numbers with no fractional or decimal part

# %% [markdown]
# #### Float - represents numbers with a decimal or fractional value.

# %%
# the // symbol stands for floor division also known as (intiger division)
84 // 2
# Out:
# 42

# %% [markdown]
# #### floor division gives you everything before the decimal

# %%
# everything from the decimal on gets removed from our answer

# %%
# The ** symbol is used to represent exponets. power of something 
7 ** 2
# Out:
# 49

# %%
# The ^ symbol (the carrot). In python it is a bit wise operator called XOR

# %%
# the % symbol is used for what we call Modulus Division
85 % 2
# Out:
# 1

# %% [markdown]
# ## 1.2 Expressions

# %% [markdown]
# Expression - A collection of operater is called an expression
#
# example:
# 6 + 6 ** 2
# 12 ** 2
# 42
#
# (12 + 5) * 6
# 17 * 6
# 102
#
# 12 + 5 * 6
# 30 + 12
# 42
#
# myVar = var1 * var2 + var3
#
# ## 1.3 Arthmitic functions

# %% [markdown]
# Python is a modular language:
# * Core Python Code
# * External Modules - imported into scripts
# import math
#
# Python like any programming language has built-functions

# %% [markdown]
# **round()** This fucntion takes a floatinf point number and rounds it off to the nearest integer

# %%
round(42.4)
# Out:
# 42

# %%
round(42.6)
# Out:
# 43

# %% [markdown]
# abs() function - computes the absolute value of a number

# %%
abs(42)
# Out:
# 42

# %%
abs(-42)

# %% [markdown]
# #### Calling a function

# %% [markdown]
# The process of using a function within your code can also be used as **Function call**

# %% [markdown]
# whenever you call a function you have to have parentheses

# %% [markdown]
# ## 1.4 Strings

# %% [markdown]
# A string is a sequence of charthers that are delimited by quotation marks single or double as long as they match
#
# myStr = "This is my string "#!!04&9"

# %%
'hello'
# Out:
# 'hello'

# %%
"world"
# Out:
# 'world'

# %%
"it's a small world"
# Out:
# "it's a small world"

# %%
'It's a small world
# Out:
#   Cell In[10], line 1
#     'It's a small world
#         ^
# SyntaxError: invalid syntax

# %%
'It\'s' 
# this is an esc char this tells interperter not to process the next charather.
# Out:
# "It's"

# %% [markdown]
# ### The + symbol with strings

# %% [markdown]
# concationates symbol + - The + sign concatinates or connects togother two strings

# %%
"well, " + "It's a big vast world"
# Out:
# "well, It's a big vast world"

# %% [markdown]
# ### strings and the * operator

# %% [markdown]
# The * Operator works with strings by making copies of a string and concatenates them together.

# %%
"spam, " * 4
# Out:
# 'spam, spam, spam, spam, '

# %% [markdown]
# ###  Strings and the Len() fucntion

# %%
len("diva")
# Out:
# 4

# %%
`Hello`
# Out:
#   Cell In[15], line 1
#     `Hello`
#     ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## 1.5 Values and Types

# %%
# type () fucntion- python will tell you what type of data something is in

type(42)
# Out:
# int

# %%
type(42.)
# Out:
# float

# %%
type('hello')
# Out:
# str

# %%
# int () function changes a valid floating point numeber to an initeger

int(42.5)
# Out:
# 42

# %%
# float() changes a valid integer to a valid floating point number 
float(42)
# Out:
# 42.0

# %%
'126'
# Out:
# '126'

# %%
type('126')
# Out:
# str

# %%
'126' / 3 unsupported type
# Out:
#   Cell In[24], line 1
#     '126' / 3 unsupported type
#               ^
# SyntaxError: invalid syntax

# %%
int("126") / 3
# Out:
# 42.0

# %%
float('12.6') * 3
# Out:
# 37.8

# %%
1,000,000 * 5
# Out:
# (1, 0, 0)

# %%
1000000
# Out:
# 1000000

# %% [markdown]
# ### natural lang

# %% [markdown]
# are languages people speak, like english, spanish, and sinhalese. They were were not technically designed by peopl, naturally evolve from human speech

# %% [markdown]
# ### formal lamg
#
# these are desginegd by people for spesfifc applications for example the notation that mathmatics use a formal language that is particuallrly good at denoting relationships
#
# ### debugging
#
# mistakes made in the process of programming have been come to be known as bugs tracking down and fixing thoses mistakes than became debugging
